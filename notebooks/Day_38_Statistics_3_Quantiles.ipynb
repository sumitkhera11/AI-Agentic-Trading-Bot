# %% [markdown]
# ## Box Plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
demo_box = pd.Series([1,2,1,3,4,5,3,50,-40,2])

# %%
plt.boxplot(demo_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21958259390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2195825abd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21958258810>],
#  'medians': [<matplotlib.lines.Line2D at 0x2195825bf50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2195826c9d0>],
#  'means': []}

# %%
demo_box.describe()
# Out:
# count    10.000000
# mean      3.100000
# std      21.273092
# min     -40.000000
# 25%       1.250000
# 50%       2.500000
# 75%       3.750000
# max      50.000000
# dtype: float64
