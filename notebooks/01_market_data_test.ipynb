# %%
1+1
# Out:
# 2

# %%
print("Notebook Working")
# Out:
# Notebook Working

# %%
from statsmodels.regression.rolling import RollingOLS
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import pandas_ta
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
print(sys.version)
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
import pandas_ta as ta

print("Installed:", ta.version)
# Out:
# Installed: 0.4.24

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
html = response.text

sp500 = pd.read_html(StringIO(html))[0]

# %%
sp500
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
print("Hello")
# Out:
# Hello

# %%
sp500['Symbol'] = sp500['Symbol'].str.replace('.','-')

# %%
symbols_list = sp500['Symbol'].unique().tolist()

symbols_list=symbols_list[:5]

end_date = pd.Timestamp.today() - pd.Timedelta(days=1)

# '2023-09-27' ko string se datetime me convert karo

start_date = end_date - pd.DateOffset(years=8)

# %%
# # Taaki model ke paas kaafi historical data ho indicators banane ke liye:
# failed = []

# for symbol in symbols_list:
#     try:
#         df = yf.download(
#             symbol,
#             start=start_date,
#             end=end_date,
#             auto_adjust=True,
#             threads=False
#         )

#         if df.empty:
#             failed.append(symbol)

#     except:
#         failed.append(symbol)

# print("Failed:", failed)
data = yf.download(
    symbols_list,
    start=start_date,
    end=end_date,
    auto_adjust=True,
    threads=False
)
# Out:
# [**********************80%*************          ]  4 of 5 completed$MMM: possibly delisted; no price data found  (1d 2018-06-18 21:42:16.748033 -> 2026-06-18 21:42:16.748033)
# [*********************100%***********************]  5 of 5 completed
#
# 1 Failed download:
# ['MMM']: possibly delisted; no price data found  (1d 2018-06-18 21:42:16.748033 -> 2026-06-18 21:42:16.748033)

# %%
data['SMA_20'] = data['Close'].rolling(20).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data['SMA_20'] = data['Close'].rolling(20).mean()
#
# File c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\frame.py:4301, in DataFrame.__setitem__(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ...

# %%
df.stack()
# Out:
# Price                   Close        High         Low        Open    Volume
# Date       Ticker
# 2018-06-19 ACN     145.172729  145.199397  143.385966  144.114889   2574400
# 2018-06-20 ACN     143.803802  145.226098  143.706019  144.897195   2026800
# 2018-06-21 ACN     142.256973  143.945953  141.901403  143.448149   2034200
# 2018-06-22 ACN     141.901443  142.674817  140.843603  142.674817   3623900
# 2018-06-25 ACN     138.816788  140.505767  138.096749  140.443549   3134500
# ...                       ...         ...         ...         ...       ...
# 2026-06-12 ACN     170.279999  171.770004  164.649994  168.440002   4040100
# 2026-06-15 ACN     165.360001  172.589996  165.050003  167.600006   6026500
# 2026-06-16 ACN     165.520004  169.789993  165.029999  165.630005   4422600
# 2026-06-17 ACN     156.009995  166.869995  155.910004  164.899994   7563200
# 2026-06-18 ACN     127.980003  134.699997  125.599998  126.500000  41701500
#
# [2011 rows x 5 columns]

# %%
df.index.names= ['date','ticker']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.index.names= ['date','ticker']
#
# File c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\indexes\base.py:1787, in Index._set_names(self, values, level)
#    1785     raise ValueError("Names must be a list-like")
#    1786 if len(values) != 1:
# -> 1787     raise ValueError(f"Length of new names must be 1, got {len(values)}")
#    1789 # GH 20527
#    1790 # All items in 'name' need to be hashable:
#    1791 validate_all_hashable(*values, error_name=f"{type(self).__name__}.name")
#
# ValueError: Length of new names must be 1, got 2

# %%
df.columns
