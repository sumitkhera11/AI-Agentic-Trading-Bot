# %% [markdown]
# ### Advance Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Day_23_AlgoTrading.csv")
df
# Out:
#     Unnamed: 0.1  Unnamed: 0           id symbol      name  \
# 0              0           0      bitcoin    btc   Bitcoin
# 1              1           1     ethereum    eth  Ethereum
# 2              2           2       tether   usdt    Tether
# 3              3           3  binancecoin    bnb       BNB
# 4              4           4     usd-coin   usdc      USDC
# ..           ...         ...          ...    ...       ...
# 95            95          95        aptos    apt     Aptos
# 96            96          96   midnight-3  night  Midnight
# 97            97          97     arbitrum    arb  Arbitrum
# 98            98          98     pump-fun   pump  Pump.fun
# 99            99          99    adi-token    adi       ADI
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...   64104.000000
# 1   https://coin-images.coingecko.com/coins/images...    1726.180000
# ...

# %%
df = df.set_index("name")["current_price"]
print(df)
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
#                 ...
# Aptos           0.657939
# Midnight        0.032902
# Arbitrum        0.084027
# Pump.fun        0.001531
# ADI             4.140000
# Name: current_price, Length: 100, dtype: float64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (100,)

# %%
df.value_counts()
# Out:
# current_price
# 1.000000        5
# 1.130000        2
# 64104.000000    1
# 589.850000      1
# 0.999878        1
#                ..
# 0.657939        1
# 0.032902        1
# 0.084027        1
# 0.001531        1
# 4.140000        1
# Name: count, Length: 95, dtype: int64

# %%
df.head()
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
# Name: current_price, dtype: float64

# %%
df.sample(5)
# Out:
# name
# BFUSD           0.998909
# Chainlink       7.950000
# Cosmos Hub      1.770000
# Bitget Token    1.760000
# Flare           0.007439
# Name: current_price, dtype: float64

# %%
df.value_counts()
df.value_counts(ascending=True)
# Out:
# current_price
# 64104.000000    1
# 1726.180000     1
# 0.998892        1
# 589.850000      1
# 0.999878        1
#                ..
# 0.657939        1
# 0.032902        1
# 4.140000        1
# 1.130000        2
# 1.000000        5
# Name: count, Length: 95, dtype: int64

# %%
df.sort_values()
df.sort_values(ascending=True)
# Out:
# name
# HTX DAO            0.000002
# Pepe               0.000003
# Shiba Inu          0.000005
# Pump.fun           0.001531
# Flare              0.007439
#                    ...
# BNB              589.850000
# Ethereum        1726.180000
# Tether Gold     4149.350000
# PAX Gold        4155.450000
# Bitcoin        64104.000000
# Name: current_price, Length: 100, dtype: float64

# %%
df.sort_index()
df.sort_index(ascending=False)
# Out:
# name
# ADI                     4.140000
# Aave                   74.570000
# Algorand                0.091602
# Aptos                   0.657939
# Arbitrum                0.084027
#                          ...
# XRP                     1.140000
# YLDS                    0.999806
# Zcash                 451.670000
# ​​Stable                0.034231
# 币安人生 (BinanceLife)      0.708101
# Name: current_price, Length: 100, dtype: float64

# %% [markdown]
# ## Series Maths Methods

# %%
df.count()
df.size
# Out:
# 100

# %%
math_ser = pd.Series([1,2,np.nan,4,5])
math_ser
print(math_ser.count())  # exclude nan values
print(math_ser.size)  # include nan values
# Out:
# 4
# 5

# %%
df.sum()
df.product()
# Out:
# np.float64(235926482.20939797)

# %%
df.mean()
# Out:
# np.float64(766.5493442933999)

# %%
df.median()
# Out:
# np.float64(1.0)

# %%
df.mode()
# Out:
# 0    1.0
# Name: current_price, dtype: float64

# %%
df.min()
# Out:
# np.float64(1.72e-06)

# %%
df.max()
# Out:
# np.float64(64104.0)

# %%
df.describe()
# Out:
# count      100.000000
# mean       766.549344
# std       6426.601226
# min          0.000002
# 25%          0.221028
# 50%          1.000000
# 75%          6.847500
# max      64104.000000
# Name: current_price, dtype: float64

# %% [markdown]
# ## Series Indexing

# %%
# integer indexing  
list_int = [100,101,102,103]
int_ser = pd.Series(list_int)
int_ser
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# dtype: int64

# %%
int_ser[0]
# Out:
# np.int64(100)

# %%
# negative indexing 
# use iloc and loc

# %%
# slicing
int_ser[:]
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# dtype: int64

# %%
print(df)
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
#                 ...
# Aptos           0.657939
# Midnight        0.032902
# Arbitrum        0.084027
# Pump.fun        0.001531
# ADI             4.140000
# Name: current_price, Length: 100, dtype: float64

# %%
int_ser[1:4]
print(df)
print(df["Bitcoin":"BNB"])
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
#                 ...
# Aptos           0.657939
# Midnight        0.032902
# Arbitrum        0.084027
# Pump.fun        0.001531
# ADI             4.140000
# Name: current_price, Length: 100, dtype: float64
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# Name: current_price, dtype: float64

# %%
# fancy indexing
df[["Tether","Bitcoin","BNB"]]
# Out:
# name
# Tether         0.998892
# Bitcoin    64104.000000
# BNB          589.850000
# Name: current_price, dtype: float64

# %% [markdown]
# ## Editing Series

# %%
int_ser[2] = 1550

# %%
int_ser
# Out:
# 0     100
# 1     101
# 2    1550
# 3     103
# dtype: int64

# %%
int_ser[4] = 147

# %%
int_ser[[2,3]] = [10000,20000]

# %%
print(len(df))
print(len(int_ser))
# Out:
# 100
# 5

# %% [markdown]
# ## Membership operator

# %%
"FLOKI" in df
"Aptos" in df
589.850000 in df.values
# Out:
# True

# %%
df
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
#                 ...
# Aptos           0.657939
# Midnight        0.032902
# Arbitrum        0.084027
# Pump.fun        0.001531
# ADI             4.140000
# Name: current_price, Length: 100, dtype: float64

# %%
# looping
for i in df.index:
    print(i)
# Out:
# Bitcoin
# Ethereum
# Tether
# BNB
# USDC
# XRP
# Solana
# TRON
# Figure Heloc
# Hyperliquid
# Dogecoin
# USDS
# Rain
# LEO Token
# Zcash
# Stellar
# WhiteBIT Coin
# Cardano
# Monero
# Chainlink
# Canton
# USD1
# Gram (prev. Toncoin)
# Ethena USDe
# Dai
# LAB
# Bitcoin Cash
# MemeCore
# Litecoin
# Hedera
# Circle USYC
# Sui
# NEAR Protocol
# Global Dollar
# PayPal USD
# Shiba Inu
# Cronos
# Avalanche
# Tether Gold
# BlackRock USD Institutional Digital Liquidity Fund
# Bittensor
# Worldcoin
# Ondo US Dollar Yield
# Uniswap
# PAX Gold
# World Liberty Financial
# Mantle
# Aster
# Ondo
# Ripple USD
# Polkadot
# OKB
# HTX DAO
# Pi Network
# Falcon USD
# Sky
# USDD
# BFUSD
# Internet Computer
# Bitget Token
# Morpho
# Pepe
# Ethereum Classic
# Aave
# Quant
# United Stables
# Invesco Short Duration US Government Securities Fund
# KuCoin
# Blockchain Capital
# Spiko EU T-Bills Money Market Fund
# USDtb
# Cosmos Hub
# Render
# Janus Henderson Anemoy Treasury Fund
# POL (ex-MATIC)
# Ethena
# ...

# %%
# Arithmetic Operators (Broascasting)
df + 100
# Out:
# name
# Bitcoin     64204.000000
# Ethereum     1826.180000
# Tether        100.998892
# BNB           689.850000
# USDC          100.999878
#                 ...
# Aptos         100.657939
# Midnight      100.032902
# Arbitrum      100.084027
# Pump.fun      100.001531
# ADI           104.140000
# Name: current_price, Length: 100, dtype: float64

# %%
df > 0.1
df[df > 0.1]
# Out:
# name
# Bitcoin                                   64104.000000
# Ethereum                                   1726.180000
# Tether                                        0.998892
# BNB                                         589.850000
# USDC                                          0.999878
#                                               ...
# YLDS                                          0.999806
# Spiko Amundi Overnight Swap Fund (EUR)        1.150000
# Usual USD                                     0.999146
# Aptos                                         0.657939
# ADI                                           4.140000
# Name: current_price, Length: 79, dtype: float64

# %% [markdown]
# ## Boolena Index on Series

# %%
(df > 0.1 ) & (df < 0.4)
df[(df > 0.1 ) & (df < 0.4)]
# Out:
# name
# TRON          0.327068
# Stellar       0.213267
# Cardano       0.161934
# Canton        0.150629
# Ondo          0.339318
# Pi Network    0.135754
# Jupiter       0.223615
# Name: current_price, dtype: float64

# %%
df == 1
df[df == 1]
# Out:
# name
# USD1                                                  1.0
# PayPal USD                                            1.0
# BlackRock USD Institutional Digital Liquidity Fund    1.0
# Ripple USD                                            1.0
# United Stables                                        1.0
# Name: current_price, dtype: float64

# %% [markdown]
# ## Plotting Graphs on Series

# %%
df.plot()
df.plot(kind="pie")
# Out:
# <Axes: xlabel='name', ylabel='current_price'>
# c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 24065 (\N{CJK UNIFIED IDEOGRAPH-5E01}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 23433 (\N{CJK UNIFIED IDEOGRAPH-5B89}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# ## Some important series methods

# %%
df.dtype
# Out:
# dtype('float64')

# %%
import sys
sys.getsizeof(df.dtype)
print(sys.getsizeof(df.dtype))
# Out:
# 120

# %%
# convert the dtype
df.astype(dtype=np.int16)
# Out:
# name
# Bitcoin    -1432
# Ethereum    1726
# Tether         0
# BNB          589
# USDC           0
#             ...
# Aptos          0
# Midnight       0
# Arbitrum       0
# Pump.fun       0
# ADI            4
# Name: current_price, Length: 100, dtype: int16

# %%
dff = sys.getsizeof(df.astype(dtype=np.int16))
sys.getsizeof(dff)
# Out:
# 28

# %%
# between
df.between(0.3, 0.5)
# or
df[(df > 0.3) & (df < 0.5)]
# Out:
# name
# TRON    0.327068
# Ondo    0.339318
# Name: current_price, dtype: float64

# %%
dfdf = df.clip(0.4,0.7)
dfdf.drop_duplicates()
# Out:
# name
# Bitcoin      0.700000
# TRON         0.400000
# Worldcoin    0.641422
# Mantle       0.537027
# Aster        0.641682
# Aptos        0.657939
# Name: current_price, dtype: float64

# %%
df.isnull()
# Out:
# name
# Bitcoin     False
# Ethereum    False
# Tether      False
# BNB         False
# USDC        False
#             ...
# Aptos       False
# Midnight    False
# Arbitrum    False
# Pump.fun    False
# ADI         False
# Name: current_price, Length: 100, dtype: bool

# %%
int_ser = pd.Series([1,2,3,np.nan,4,5])
int_ser.isnull()
int_ser.isnull().sum()
int_ser.dropna()
int_ser.fillna("Missing Values")
int_ser.fillna(int_ser.mean())
# Out:
# 0               1.0
# 1               2.0
# 2               3.0
# 3    Missing Values
# 4               4.0
# 5               5.0
# dtype: object

# %%
df
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
#                 ...
# Aptos           0.657939
# Midnight        0.032902
# Arbitrum        0.084027
# Pump.fun        0.001531
# ADI             4.140000
# Name: current_price, Length: 100, dtype: float64

# %%
df.isin([0.998892,4.140000])
# Out:
# name
# Bitcoin     False
# Ethereum    False
# Tether       True
# BNB         False
# USDC        False
#             ...
# Aptos       False
# Midnight    False
# Arbitrum    False
# Pump.fun    False
# ADI          True
# Name: current_price, Length: 100, dtype: bool

# %%
df.apply(lambda x: round(x,2))
# Out:
# name
# Bitcoin     64104.00
# Ethereum     1726.18
# Tether          1.00
# BNB           589.85
# USDC            1.00
#               ...
# Aptos           0.66
# Midnight        0.03
# Arbitrum        0.08
# Pump.fun        0.00
# ADI             4.14
# Name: current_price, Length: 100, dtype: float64

# %%
#copy
