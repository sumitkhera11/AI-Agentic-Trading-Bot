# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series

# %%
list_str = ["Apple","Microsoft","Ethereum"]
pd.Series(list_str)
# Out:
# 0        Apple
# 1    Microsoft
# 2     Ethereum
# dtype: object

# %%
list_int = [100,101,102,103]
pd.Series(list_int)
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# dtype: int64

# %%
list_int = [100,101,102,103]
list_str = ["Apple","Microsoft","Ethereum", "Nvidia"]
ser_cust = pd.Series(list_int,index=list_str)
type(ser_cust)
# Out:
# pandas.core.series.Series

# %%
ser_cust["Apple"]
ser_cust[0]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11424\4130743153.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser_cust[0]
# np.int64(100)

# %%
list_int = [100,101,102,103]
list_str = ["Apple","Microsoft","Ethereum", "Nvidia"]
pd.Series(list_int,index=list_str,name="The Stock Prices of Sumit")
# Out:
# Apple        100
# Microsoft    101
# Ethereum     102
# Nvidia       103
# Name: The Stock Prices of Sumit, dtype: int64

# %% [markdown]
# ## Series from dict

# %%
dict_ser  = {"Apple": 100, "Microsoft":200,"Bitcoin":300000,"Etherum":400}
dict_ser
dict_ser=pd.Series(dict_ser,name="The Stock prices of Sumit")
type(dict_ser)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Series Attributes

# %%
dict_ser.dtype
dict_ser.size
dict_ser.name
dict_ser.is_unique
dict_ser.index
dict_ser.values
type(dict_ser.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Series using read_csv

# %%
# with one col

import requests
import pandas as pd

# Define the API endpoint
url = "https://api.coingecko.com/api/v3/coins/markets"

# Define the parameters for the API request
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 100,
    "page": 1,
    "sparkline": False
}

# Make the API request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data
    data = response.json()

    # Create a DataFrame from the data
    df = pd.DataFrame(data)

    # Display the DataFrame
    print(df.head())
else:
    print(f"Failed to fetch data: {response.status_code}")
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4     usd-coin   usdc      USDC
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...   64104.000000
# 1  https://coin-images.coingecko.com/coins/images...    1726.180000
# 2  https://coin-images.coingecko.com/coins/images...       0.998892
# 3  https://coin-images.coingecko.com/coins/images...     589.850000
# 4  https://coin-images.coingecko.com/coins/images...       0.999878
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1285121763243                1            1285121763243  1.397490e+10
# 1   208359927407                2             208359927407  8.944073e+09
# 2   186220413890                3             191681014110  2.925259e+10
# ...

# %%
df
# Out:
#              id symbol      name  \
# 0       bitcoin    btc   Bitcoin
# 1      ethereum    eth  Ethereum
# 2        tether   usdt    Tether
# 3   binancecoin    bnb       BNB
# 4      usd-coin   usdc      USDC
# ..          ...    ...       ...
# 95        aptos    apt     Aptos
# 96   midnight-3  night  Midnight
# 97     arbitrum    arb  Arbitrum
# 98     pump-fun   pump  Pump.fun
# 99    adi-token    adi       ADI
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...   64104.000000
# 1   https://coin-images.coingecko.com/coins/images...    1726.180000
# 2   https://coin-images.coingecko.com/coins/images...       0.998892
# 3   https://coin-images.coingecko.com/coins/images...     589.850000
# 4   https://coin-images.coingecko.com/coins/images...       0.999878
# ..                                                ...            ...
# 95  https://coin-images.coingecko.com/coins/images...       0.657939
# ...

# %%
df.to_csv("Day_23_AlgoTrading.csv")

# %%
df = pd.read_csv("Day_23_AlgoTrading.csv")
df
# Out:
#     Unnamed: 0.1  Unnamed: 0           id symbol      name  \
# 0              0           0      bitcoin    btc   Bitcoin
# 1              1           1     ethereum    eth  Ethereum
# 2              2           2       tether   usdt    Tether
# 3              3           3  binancecoin    bnb       BNB
# 4              4           4     usd-coin   usdc      USDC
# ..           ...         ...          ...    ...       ...
# 95            95          95        aptos    apt     Aptos
# 96            96          96   midnight-3  night  Midnight
# 97            97          97     arbitrum    arb  Arbitrum
# 98            98          98     pump-fun   pump  Pump.fun
# 99            99          99    adi-token    adi       ADI
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...   64104.000000
# 1   https://coin-images.coingecko.com/coins/images...    1726.180000
# ...

# %%
df  = df[["name","current_price"]]

# %%
df
# Out:
#         name  current_price
# 0    Bitcoin   64104.000000
# 1   Ethereum    1726.180000
# 2     Tether       0.998892
# 3        BNB     589.850000
# 4       USDC       0.999878
# ..       ...            ...
# 95     Aptos       0.657939
# 96  Midnight       0.032902
# 97  Arbitrum       0.084027
# 98  Pump.fun       0.001531
# 99       ADI       4.140000
#
# [100 rows x 2 columns]

# %%
type(df[["name","current_price"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# convert data frame to series
ser = df.squeeze()
ser
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
#                 ...
# Aptos           0.657939
# Midnight        0.032902
# Arbitrum        0.084027
# Pump.fun        0.001531
# ADI             4.140000
# Name: current_price, Length: 100, dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
df  = df.set_index("name")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df  = df.set_index("name")
#       2 df
#
# File c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\frame.py:6122, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['name'] are in the columns"

# %%
ser
# Out:
# name
# Bitcoin     64104.000000
# Ethereum     1726.180000
# Tether          0.998892
# BNB           589.850000
# USDC            0.999878
#                 ...
# Aptos           0.657939
# Midnight        0.032902
# Arbitrum        0.084027
# Pump.fun        0.001531
# ADI             4.140000
# Name: current_price, Length: 100, dtype: float64

# %%
import sys
sys.getsizeof(ser)
# Out:
# 11769

# %%
#change data type
aser = ser.astype(np.float32)
sys.getsizeof(aser)
# Out:
# 11369
