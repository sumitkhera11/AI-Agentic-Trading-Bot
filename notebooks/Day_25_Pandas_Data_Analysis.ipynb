# %% [markdown]
# ## Creating DataFrame

# %%
import pandas as pd
import numpy as np

# %%
price_data = [
    [100,200,400,600],
    [100,200,400,600],
    [100,200,400,600],
    [100,200,400,600],
]
list_df = pd.DataFrame(price_data)
type(list_df)
# Out:
# pandas.core.frame.DataFrame

# %%
price_data = {
    "Name": ["Apple", "Microsoft", "Tesla", "Meta"],
    "Open" : [100,200,400,600],
    "High":[100,200,400,600],
    "Low": [100,200,400,600],
    "Close":[100,200,400,600],
}
dict_df = pd.DataFrame(price_data)
dict_df.set_index("Name",inplace=True)

# %%
algo_df = pd.read_csv("../data/raw/algotrading_combined_dataset.csv")

# %%
funda_df = pd.read_csv("../data/raw/fundamental_research_dataset_large.csv")

# %%
algo_df.shape
# Out:
# (32870, 7)

# %%
funda_df.shape
# Out:
# (1050, 10)

# %%
algo_df.dtypes
funda_df.dtypes
# Out:
# Ticker                 object
# Company Name           object
# Sector                 object
# Industry               object
# Market Cap (B)        float64
# EPS                   float64
# P/E Ratio             float64
# Dividend Yield (%)    float64
# P/B Ratio             float64
# D/E Ratio             float64
# dtype: object

# %%
algo_df.index
funda_df.index
# Out:
# RangeIndex(start=0, stop=1050, step=1)

# %%
algo_df.columns
funda_df.columns
# Out:
# Index(['Ticker', 'Company Name', 'Sector', 'Industry', 'Market Cap (B)', 'EPS',
#        'P/E Ratio', 'Dividend Yield (%)', 'P/B Ratio', 'D/E Ratio'],
#       dtype='object')

# %%
algo_df.values
# Out:
# array([['2015-01-01', 'AAPL', 101.03184941004706, ..., 98.85235437937838,
#         101.19741015525102, 344567.0],
#        ['2015-01-02', 'AAPL', 100.8664959216968, ..., 99.5689811441504,
#         101.22006444647305, 310521.0],
#        ['2015-01-05', 'AAPL', 101.1644889006902, ..., 100.92012448620686,
#         101.3398717110426, nan],
#        ...,
#        ['2018-03-09', 'AMZN', 98.07461328046368, ..., 96.20317673355092,
#         97.48761554705614, 76911.0],
#        ['2018-05-02', 'LTC/USD', 103.44322425714826, ...,
#         103.1592860645143, nan, 552764.0],
#        ['2020-09-18', 'ETH/USD', 164.75532933160764, ...,
#         164.75532933160764, 164.72202588322403, 816832.0]],
#       shape=(32870, 7), dtype=object)

# %%
algo_df.head()
# Out:
#          Date Ticker        Open        High         Low       Close    Volume
# 0  2015-01-01   AAPL  101.031849  101.329723   98.852354  101.197410  344567.0
# 1  2015-01-02   AAPL  100.866496  100.866496   99.568981  101.220064  310521.0
# 2  2015-01-05   AAPL  101.164489  101.176821  100.920124  101.339872       NaN
# 3  2015-01-06   AAPL         NaN  103.203859  102.287356  101.777905  295025.0
# 4  2015-01-07   AAPL  102.744728  104.050309  102.211701  102.090310  439080.0

# %%
funda_df.tail(20)
# Out:
#      Ticker             Company Name            Sector            Industry  \
# 1030  BRK.B  Berkshire Hathaway Inc.        Technology            Software
# 1031      V                Visa Inc.        Technology      Semiconductors
# 1032  GOOGL            Alphabet Inc.        Healthcare       Biotechnology
# 1033      V                Visa Inc.    Consumer Goods           Beverages
# 1034   AAPL               Apple Inc.        Healthcare       Biotechnology
# 1035    JPM     JPMorgan Chase & Co.         Utilities     Water Utilities
# 1036    JNJ        Johnson & Johnson         Utilities       Gas Utilities
# 1037   TSLA              Tesla, Inc.  Industrial Goods       Manufacturing
# 1038  GOOGL            Alphabet Inc.  Industrial Goods       Manufacturing
# 1039      V                Visa Inc.    Consumer Goods       Food Products
# 1040    JPM     JPMorgan Chase & Co.        Healthcare     Medical Devices
# ...

# %%
algo_df.sample(30)
# Out:
#              Date   Ticker        Open        High         Low       Close  \
# 17302  2017-04-28  AUD/USD   95.082211   95.725594   95.066781   95.640353
# 3846   2021-09-29     GOOG  190.668730  191.360091  190.668730  190.618999
# 26772  2021-08-17  XRP/USD  186.238959         NaN  185.112391  186.604519
# 2554   2016-10-17     GOOG  104.711131  105.954192  104.356621  105.656911
# 26015  2018-09-21  XRP/USD  125.966912  127.076113  124.003525  125.519204
# 27721  2017-04-06  LTC/USD   92.361032         NaN   91.545386   91.394455
# 8424   2015-04-17     TSLA   91.464373   93.685501   91.464373   92.152296
# 12654  2015-07-06  GBP/USD   87.667309   90.611261   86.723057   88.444862
# 1929   2022-05-25     AAPL  179.582211  180.427300  179.028622         NaN
# 26944  2022-04-14  XRP/USD  181.285289  182.759552  181.285289  182.933261
# 18106  2020-05-28  AUD/USD  149.745379  151.343442  148.310433  150.493761
# ...

# %%
algo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32870 entries, 0 to 32869
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    32870 non-null  object
#  1   Ticker  32870 non-null  object
#  2   Open    31495 non-null  float64
#  3   High    31302 non-null  float64
#  4   Low     31090 non-null  float64
#  5   Close   30929 non-null  float64
#  6   Volume  30802 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.8+ MB

# %%
algo_df.describe()
# Out:
#                Open          High           Low         Close         Volume
# count  31495.000000  31302.000000  31090.000000  30929.000000   30802.000000
# mean     133.600798    134.416157    132.420885    133.369927  492483.749302
# std       35.566539     35.716248     35.661035     35.715660  283838.912786
# min       83.254666     84.062713     81.978737     83.411785    1203.000000
# 25%       98.251137     98.928322     97.038250     97.824039  248663.000000
# 50%      132.147803    132.534488    130.718141    131.890827  490922.000000
# 75%      169.633748    171.193317    168.811891    170.103620  725434.000000
# max      196.068319    196.712825    194.736434    196.349019  999653.000000

# %%
algo_df.isnull()
algo_df.isnull().sum()
funda_df.isnull().sum()
# Out:
# Ticker                  0
# Company Name            0
# Sector                  0
# Industry                0
# Market Cap (B)        104
# EPS                   103
# P/E Ratio             118
# Dividend Yield (%)     99
# P/B Ratio             116
# D/E Ratio              97
# dtype: int64

# %%
algo_df.duplicated()
algo_df.duplicated().sum()
funda_df.duplicated().sum()
# Out:
# np.int64(50)

# %%
# rename column name
algo_df.rename(columns={'High': 'Max', 'Low': 'Min'})
# Out:
#              Date   Ticker        Open         Max         Min       Close  \
# 0      2015-01-01     AAPL  101.031849  101.329723   98.852354  101.197410
# 1      2015-01-02     AAPL  100.866496  100.866496   99.568981  101.220064
# 2      2015-01-05     AAPL  101.164489  101.176821  100.920124  101.339872
# 3      2015-01-06     AAPL         NaN  103.203859  102.287356  101.777905
# 4      2015-01-07     AAPL  102.744728  104.050309  102.211701  102.090310
# ...           ...      ...         ...         ...         ...         ...
# 32865  2021-08-02     AMZN  184.443237  185.375089  183.176491  183.087397
# 32866  2017-01-24     AAPL   92.780364   93.092012   91.238510         NaN
# 32867  2018-03-09     AMZN   98.074613   99.154029   96.203177   97.487616
# 32868  2018-05-02  LTC/USD  103.443224  105.575739  103.159286         NaN
# 32869  2020-09-18  ETH/USD  164.755329  166.936724  164.755329  164.722026
#
#          Volume
# 0      344567.0
# 1      310521.0
# ...

# %% [markdown]
# ## Maths Methods

# %%
algo_df.sum()
funda_df.sum()
# Out:
# Ticker                AAPLGOOGLMSFTAMZNTSLAFBBRK.BJNJJPMVAAPLGOOGLMS...
# Company Name          Apple Inc.Alphabet Inc.Microsoft CorporationAm...
# Sector                TechnologyFinanceFinanceHealthcareEnergyConsum...
# Industry              SemiconductorsInvestment ServicesBanksPharmace...
# Market Cap (B)                                                232554.06
# EPS                                                              176.64
# P/E Ratio                                                      25753.87
# Dividend Yield (%)                                              4699.86
# P/B Ratio                                                       9584.88
# D/E Ratio                                                       1438.18
# dtype: object

# %%
algo_df['High'].mean()
# Out:
# np.float64(134.41615698695395)

# %%
algo_df['High'].var()
# Out:
# np.float64(1275.6503714830637)

# %%
funda_df
# Out:
#      Ticker           Company Name            Sector             Industry  \
# 0      AAPL             Apple Inc.        Technology       Semiconductors
# 1     GOOGL          Alphabet Inc.           Finance  Investment Services
# 2      MSFT  Microsoft Corporation           Finance                Banks
# 3      AMZN       Amazon.com, Inc.        Healthcare      Pharmaceuticals
# 4      TSLA            Tesla, Inc.            Energy            Oil & Gas
# ...     ...                    ...               ...                  ...
# 1045    JNJ      Johnson & Johnson    Consumer Goods   Household Products
# 1046   TSLA            Tesla, Inc.  Industrial Goods         Construction
# 1047  GOOGL          Alphabet Inc.         Utilities      Water Utilities
# 1048      V              Visa Inc.  Industrial Goods         Construction
# 1049    JNJ      Johnson & Johnson        Technology       Semiconductors
#
#       Market Cap (B)   EPS  P/E Ratio  Dividend Yield (%)  P/B Ratio  \
# ...

# %% [markdown]
# ## Select col from dataFrame

# %%
funda_df["Ticker"]
funda_df[["Ticker", "Sector"]]
# Out:
#      Ticker            Sector
# 0      AAPL        Technology
# 1     GOOGL           Finance
# 2      MSFT           Finance
# 3      AMZN        Healthcare
# 4      TSLA            Energy
# ...     ...               ...
# 1045    JNJ    Consumer Goods
# 1046   TSLA  Industrial Goods
# 1047  GOOGL         Utilities
# 1048      V  Industrial Goods
# 1049    JNJ        Technology
#
# [1050 rows x 2 columns]

# %%
algo_df.iloc[0]
algo_df.iloc[0:4]
algo_df.iloc[0:4:2]
# Out:
#          Date Ticker        Open        High         Low       Close    Volume
# 0  2015-01-01   AAPL  101.031849  101.329723   98.852354  101.197410  344567.0
# 2  2015-01-05   AAPL  101.164489  101.176821  100.920124  101.339872       NaN

# %%
#Fancy Indexing
algo_df.iloc[[1,4,7,9,10,11]]
# Out:
#           Date Ticker        Open        High         Low       Close  \
# 1   2015-01-02   AAPL  100.866496  100.866496   99.568981  101.220064
# 4   2015-01-07   AAPL  102.744728  104.050309  102.211701  102.090310
# 7   2015-01-12   AAPL  104.973922  105.968278  103.491534  104.203536
# 9   2015-01-14   AAPL  104.211973  104.931374  104.088945  103.762217
# 10  2015-01-15   AAPL  104.830035  104.830035  102.731556  104.636914
# 11  2015-01-16   AAPL         NaN  103.846070  102.675870  103.813307
#
#       Volume
# 1   310521.0
# 4   439080.0
# 7   779883.0
# 9   427009.0
# 10  557718.0
# 11  703922.0

# %%
algo_df
# Out:
#              Date   Ticker        Open        High         Low       Close  \
# 0      2015-01-01     AAPL  101.031849  101.329723   98.852354  101.197410
# 1      2015-01-02     AAPL  100.866496  100.866496   99.568981  101.220064
# 2      2015-01-05     AAPL  101.164489  101.176821  100.920124  101.339872
# 3      2015-01-06     AAPL         NaN  103.203859  102.287356  101.777905
# 4      2015-01-07     AAPL  102.744728  104.050309  102.211701  102.090310
# ...           ...      ...         ...         ...         ...         ...
# 32865  2021-08-02     AMZN  184.443237  185.375089  183.176491  183.087397
# 32866  2017-01-24     AAPL   92.780364   93.092012   91.238510         NaN
# 32867  2018-03-09     AMZN   98.074613   99.154029   96.203177   97.487616
# 32868  2018-05-02  LTC/USD  103.443224  105.575739  103.159286         NaN
# 32869  2020-09-18  ETH/USD  164.755329  166.936724  164.755329  164.722026
#
#          Volume
# 0      344567.0
# 1      310521.0
# ...

# %%
funda_df.loc[["AAPL","AMZN" ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 funda_df.loc[["AAPL","AMZN"]]
#
# File c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\dell\Documents\programming\core_ai\PROJECT\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
# ...

# %%
funda_df.iloc[0:10]
funda_df.iloc[0:10:2]
# Out:
#   Ticker             Company Name      Sector        Industry  Market Cap (B)  \
# 0   AAPL               Apple Inc.  Technology  Semiconductors          458.13
# 2   MSFT    Microsoft Corporation     Finance           Banks          276.46
# 4   TSLA              Tesla, Inc.      Energy       Oil & Gas          248.55
# 6  BRK.B  Berkshire Hathaway Inc.  Technology        Hardware             NaN
# 8    JPM     JPMorgan Chase & Co.     Finance           Banks          260.95
#
#     EPS  P/E Ratio  Dividend Yield (%)  P/B Ratio  D/E Ratio
# 0 -9.78      44.16                2.19       9.17       2.56
# 2  5.09       6.73                0.27       1.76       1.31
# 4  9.92      27.04                2.20      10.20       0.12
# 6 -4.01        NaN                6.92       8.03       0.08
# 8  0.21      21.25                7.18      12.03       1.52

# %%
funda_df.iloc[0:5,0:4]
# Out:
#   Ticker           Company Name      Sector             Industry
# 0   AAPL             Apple Inc.  Technology       Semiconductors
# 1  GOOGL          Alphabet Inc.     Finance  Investment Services
# 2   MSFT  Microsoft Corporation     Finance                Banks
# 3   AMZN       Amazon.com, Inc.  Healthcare      Pharmaceuticals
# 4   TSLA            Tesla, Inc.      Energy            Oil & Gas

# %%
funda_df
# Out:
#      Ticker           Company Name            Sector             Industry  \
# 0      AAPL             Apple Inc.        Technology       Semiconductors
# 1     GOOGL          Alphabet Inc.           Finance  Investment Services
# 2      MSFT  Microsoft Corporation           Finance                Banks
# 3      AMZN       Amazon.com, Inc.        Healthcare      Pharmaceuticals
# 4      TSLA            Tesla, Inc.            Energy            Oil & Gas
# ...     ...                    ...               ...                  ...
# 1045    JNJ      Johnson & Johnson    Consumer Goods   Household Products
# 1046   TSLA            Tesla, Inc.  Industrial Goods         Construction
# 1047  GOOGL          Alphabet Inc.         Utilities      Water Utilities
# 1048      V              Visa Inc.  Industrial Goods         Construction
# 1049    JNJ      Johnson & Johnson        Technology       Semiconductors
#
#       Market Cap (B)   EPS  P/E Ratio  Dividend Yield (%)  P/B Ratio  \
# ...

# %%
funda_df.loc[0:4,"Company Name": "Market Cap (B)"]
# Out:
#             Company Name      Sector             Industry  Market Cap (B)
# 0             Apple Inc.  Technology       Semiconductors          458.13
# 1          Alphabet Inc.     Finance  Investment Services          215.85
# 2  Microsoft Corporation     Finance                Banks          276.46
# 3       Amazon.com, Inc.  Healthcare      Pharmaceuticals          349.40
# 4            Tesla, Inc.      Energy            Oil & Gas          248.55

# %%
algo_df.loc[0:4,"Date":"Close"]
# Out:
#          Date Ticker        Open        High         Low       Close
# 0  2015-01-01   AAPL  101.031849  101.329723   98.852354  101.197410
# 1  2015-01-02   AAPL  100.866496  100.866496   99.568981  101.220064
# 2  2015-01-05   AAPL  101.164489  101.176821  100.920124  101.339872
# 3  2015-01-06   AAPL         NaN  103.203859  102.287356  101.777905
# 4  2015-01-07   AAPL  102.744728  104.050309  102.211701  102.090310

# %%
algo_df["New Col"] = "Sumit"

# %%
algo_df
# Out:
#              Date   Ticker        Open        High         Low       Close  \
# 0      2015-01-01     AAPL  101.031849  101.329723   98.852354  101.197410
# 1      2015-01-02     AAPL  100.866496  100.866496   99.568981  101.220064
# 2      2015-01-05     AAPL  101.164489  101.176821  100.920124  101.339872
# 3      2015-01-06     AAPL         NaN  103.203859  102.287356  101.777905
# 4      2015-01-07     AAPL  102.744728  104.050309  102.211701  102.090310
# ...           ...      ...         ...         ...         ...         ...
# 32865  2021-08-02     AMZN  184.443237  185.375089  183.176491  183.087397
# 32866  2017-01-24     AAPL   92.780364   93.092012   91.238510         NaN
# 32867  2018-03-09     AMZN   98.074613   99.154029   96.203177   97.487616
# 32868  2018-05-02  LTC/USD  103.443224  105.575739  103.159286         NaN
# 32869  2020-09-18  ETH/USD  164.755329  166.936724  164.755329  164.722026
#
#          Volume New Col
# 0      344567.0   Sumit
# ...

# %%
algo_df["New Close"] = algo_df["Close"] * 100

# %%
algo_df
# Out:
#              Date   Ticker        Open        High         Low       Close  \
# 0      2015-01-01     AAPL  101.031849  101.329723   98.852354  101.197410
# 1      2015-01-02     AAPL  100.866496  100.866496   99.568981  101.220064
# 2      2015-01-05     AAPL  101.164489  101.176821  100.920124  101.339872
# 3      2015-01-06     AAPL         NaN  103.203859  102.287356  101.777905
# 4      2015-01-07     AAPL  102.744728  104.050309  102.211701  102.090310
# ...           ...      ...         ...         ...         ...         ...
# 32865  2021-08-02     AMZN  184.443237  185.375089  183.176491  183.087397
# 32866  2017-01-24     AAPL   92.780364   93.092012   91.238510         NaN
# 32867  2018-03-09     AMZN   98.074613   99.154029   96.203177   97.487616
# 32868  2018-05-02  LTC/USD  103.443224  105.575739  103.159286         NaN
# 32869  2020-09-18  ETH/USD  164.755329  166.936724  164.755329  164.722026
#
#          Volume New Col     New Close
# ...
