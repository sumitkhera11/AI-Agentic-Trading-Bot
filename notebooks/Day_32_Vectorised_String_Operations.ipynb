# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
# python list are little bit slower
price = [100,200,300,400,500]
mprice= []
for i in price:
    mprice.append(i+10)
print(mprice)
# Out:
# [110, 210, 310, 410, 510]

# %%
# python list are little bit slower 
# now perform the same operation on large data set'
# benifit of vectorized operations
    # - can even smooth run on none values
price = [100,200,300,np.nan, 400,500]
npprice = np.array(price)
npprice + 10
# Out:
# array([110., 210., 310.,  nan, 410., 510.])

# %%
# .str accessor missing values ko handle kar leta hai.
ticker = ['APPL','MSFT','META',None,'HPCL']
ser = pd.Series(ticker)

# string operation on Series and on Pandas

#string accessor
ser.str.lower()
# Out:
# 0    appl
# 1    msft
# 2    meta
# 3     NaN
# 4    hpcl
# dtype: str

# %%
ser.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df = pd.read_csv("../data/raw/constituents-financials.csv")
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# 1             27.76        1.147959            1.70        68.39
# 2             22.51        1.908982            0.26        64.60
# 3             19.41        2.499560            3.29       125.86
# 4             25.47        1.714470            5.44       162.60
# ..              ...             ...             ...          ...
# 500           30.94        1.170079            1.83        76.81
# 501           27.25        1.797080            4.07        86.93
# 502           14.32        0.794834            9.01       133.49
# 503           17.73        1.480933            2.60        55.61
# 504           32.80        0.682372            1.65        80.13
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0         175.490  138721055226  9.048000e+09     4.390271       11.34
# 1          48.925   10783419933  6.010000e+08     3.575483        6.35
# 2          42.280  102121042306  5.744000e+09     3.740480        3.19
# 3          60.050  181386347059  1.031000e+10     6.291571       26.14
# 4         114.820   98765855553  5.643228e+09     2.604117       10.62
# ..            ...           ...           ...          ...         ...
# 500        46.860   12915021000  7.220000e+08     2.726209        5.31
# 501        62.850   27003303098  2.289000e+09     6.313636      212.08
# 502       108.170   24454698119  2.007400e+09     3.164895        2.39
# 503        38.430   10670678640  0.000000e+00     3.794579        1.42
# 504        52.000   35991109776  1.734000e+09     9.280896       18.09
#
#                                            SEC Filings
# 0    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4    http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..                                                 ...
# 500  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 503  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 504  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [505 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          505 non-null    str
#  1   Name            505 non-null    str
#  2   Sector          505 non-null    str
#  3   Price           505 non-null    float64
#  4   Price/Earnings  503 non-null    float64
#  5   Dividend Yield  505 non-null    float64
#  6   Earnings/Share  505 non-null    float64
#  7   52 Week Low     505 non-null    float64
#  8   52 Week High    505 non-null    float64
#  9   Market Cap      505 non-null    int64
#  10  EBITDA          505 non-null    float64
#  11  Price/Sales     505 non-null    float64
#  12  Price/Book      497 non-null    float64
#  13  SEC Filings     505 non-null    str
# dtypes: float64(9), int64(1), str(4)
# memory usage: 55.4 KB

# %%
dfs= df[['Symbol','Name','Sector','SEC Filings']]

# %%
# str accessor works on Series not on DataFrame
dfs['Name'].str.lower()
dfs['Name'].str.upper()
dfs['Name'].str.capitalize()
dfs['Name'].str.len()

dfs[dfs['Name'].str.len() > 22]

# it will remove the leading and trailing spaces
dfs['Name'].str.strip()
dfs['Name'].str.split()
dfs[dfs['Name'].str.split().str.len() > 4]
# Out:
#     Symbol                                  Name                  Sector  \
# 15     APD          Air Products & Chemicals Inc               Materials
# 19     ARE   Alexandria Real Estate Equities Inc             Real Estate
# 37     AWK      American Water Works Company Inc               Utilities
# 56     AJG             Arthur J. Gallagher & Co.              Financials
# 64    BHGE            Baker Hughes, a GE Company                  Energy
# 202   FBHS        Fortune Brands Home & Security             Industrials
# 258   JBHT         J. B. Hunt Transport Services             Industrials
# 277     LH   Laboratory Corp. of America Holding             Health Care
# 436     BK     The Bank of New York Mellon Corp.              Financials
# 452   FOXA      Twenty-First Century Fox Class A  Consumer Discretionary
# 453    FOX      Twenty-First Century Fox Class B  Consumer Discretionary
# 457   ULTA  Ulta Salon Cosmetics & Fragrance Inc  Consumer Discretionary
#
#                                            SEC Filings
# 15   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 19   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 37   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 56   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 64   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 202  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 258  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 277  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 436  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 452  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 453  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 457  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
# replace
dfs['Name'].str.replace(' ','-')
# Out:
# 0                  3M-Company
# 1             A.O.-Smith-Corp
# 2         Abbott-Laboratories
# 3                 AbbVie-Inc.
# 4               Accenture-plc
#                 ...
# 500                Xylem-Inc.
# 501           Yum!-Brands-Inc
# 502    Zimmer-Biomet-Holdings
# 503             Zions-Bancorp
# 504                    Zoetis
# Name: Name, Length: 505, dtype: str

# %%
#startswith
dfs[dfs['Name'].str.startswith('A')]
dfs[dfs['Name'].str.endswith('p')]

dfs[(dfs['Name'].str.startswith('A')) & (df['Name'].str.endswith('A'))]

dfs[dfs['Name'].str.isdigit()]
dfs[dfs['Name'].str.isalpha()]
# Out:
#     Symbol            Name                  Sector  \
# 22    ALLE        Allegion             Industrials
# 45    ANDV        Andeavor                  Energy
# 46    ANSS           ANSYS  Information Technology
# 73     BLK       BlackRock              Financials
# 76     BWA      BorgWarner  Consumer Discretionary
# 81    AVGO        Broadcom  Information Technology
# 100   CERN          Cerner             Health Care
# 126    COP  ConocoPhillips                  Energy
# 154   DWDP       DowDuPont               Materials
# 174   EQIX         Equinix             Real Estate
# 232   HOLX         Hologic             Health Care
# 245   INCY          Incyte             Health Care
# 267    KEY         KeyCorp              Financials
# 288    LYB  LyondellBasell               Materials
# 290    MAC        Macerich             Real Estate
# 324   NAVI         Navient              Financials
# 325   NTAP          NetApp  Information Technology
# 334    NKE            Nike  Consumer Discretionary
# 337    JWN       Nordstrom  Consumer Discretionary
# 348    OKE           ONEOK                  Energy
# 355   PYPL          PayPal  Information Technology
# 359    PKI     PerkinElmer             Health Care
# 360   PRGO         Perrigo             Health Care
# 376    PLD        Prologis             Real Estate
# 382   QRVO           Qorvo  Information Technology
# 392   REGN       Regeneron             Health Care
# 395    RMD          ResMed             Health Care
# 433    FTI      TechnipFMC                  Energy
# 451   TRIP     TripAdvisor  Consumer Discretionary
# 504    ZTS          Zoetis             Health Care
#
#                                            SEC Filings
# 22   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 45   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 46   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 73   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 76   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 81   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 100  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 126  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 154  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 174  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 232  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 245  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 267  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 288  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 290  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 324  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 325  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 334  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 337  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 348  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 355  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 359  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 360  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 376  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 382  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 392  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 395  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 433  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 451  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 504  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
# applying regex
dfs[dfs['Name'].str.contains('John')]
dfs[dfs['Name'].str.contains('john',case=False)]
# Out:
#     Symbol                            Name       Sector  \
# 261    JNJ               Johnson & Johnson  Health Care
# 262    JCI  Johnson Controls International  Industrials
#
#                                            SEC Filings
# 261  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 262  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
# access the last name
dfs['Name'].str.split().str[-1]
dfs['Last_Name'] = dfs['Name'].str.split().str[-1]

# %%
dfs['Last_Name']
# Out:
# 0           Company
# 1              Corp
# 2      Laboratories
# 3              Inc.
# 4               plc
#            ...
# 500            Inc.
# 501             Inc
# 502        Holdings
# 503         Bancorp
# 504          Zoetis
# Name: Last_Name, Length: 505, dtype: object

# %%
dfs[(dfs['Last_Name'].str.startswith('C')) & (dfs['Last_Name'].str.endswith('y'))]
# Out:
#     Symbol                          Name                  Sector  \
# 0      MMM                    3M Company             Industrials
# 64    BHGE    Baker Hughes, a GE Company                  Energy
# 75      BA                Boeing Company             Industrials
# 168    EMR      Emerson Electric Company             Industrials
# 314    TAP  Molson Coors Brewing Company        Consumer Staples
# 437    CLX            The Clorox Company        Consumer Staples
# 439    HSY           The Hershey Company        Consumer Staples
# 440    MOS            The Mosaic Company               Materials
# 442    DIS       The Walt Disney Company  Consumer Discretionary
# 449   TSCO        Tractor Supply Company  Consumer Discretionary
# 489    WRK              WestRock Company               Materials
#
#                                            SEC Filings Last Name
# 0    http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 64   http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 75   http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 168  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 314  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 437  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 439  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 440  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 442  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 449  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company
# 489  http://www.sec.gov/cgi-bin/browse-edgar?action...   Company

# %%
# find last name starting with vowel
df[df['Last Name'].str.contains('^[aeiou]')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Dell\Documents\Projects\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Last Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 2
#       1 # find last name starting with vowel
# ----> 2 df[df['Last Name'].str.contains('^[aeiou]')]
#
# File c:\Users\Dell\Documents\Projects\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\Dell\Documents\Projects\AI-Agentic-Trading-Bot\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Last Name'
