# %%
print("Hello")
import pandas as pd
import numpy as np

df = pd.DataFrame({"A":[1,2,3]})
df
# Out:
# Hello
#    A
# 0  1
# 1  2
# 2  3

# %%
df

# %%
print("hello")

import pandas as pd
df = pd.DataFrame({"A":[1,2,3]})

df
# Out:
# hello
#    A
# 0  1
# 1  2
# 2  3
