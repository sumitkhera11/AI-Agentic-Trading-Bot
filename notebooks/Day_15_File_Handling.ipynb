# %%
import pandas as pd

df = pd.read_csv('../data/raw/stock_data.csv')

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('../data/raw/stock_data.csv')
#       4
#       5 print(df.head())
#
# ...

# %%
# f = open("../data/raw/stock_data.csv","w")

# f.write("Symbol,Price\n")
# f.write("AAPL,298\n")
# f.write("RELIANCE,111111\n")
# Out:
# 16

# %%
import os
import pandas as pd

stock_data = {
    "Symbol":["AAPL","RELIANCE"],
    "Price":[298,88888888]
}

df = pd.DataFrame(stock_data)

os.makedirs(
    "../data/raw",
    exist_ok=True
)

df.to_csv(
    "../data/raw/stock_data.csv",
    index=False
)

print("File saved successfully")
# Out:
# File saved successfully
